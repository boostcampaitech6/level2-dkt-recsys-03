# %% [markdown]
# ## Data

# %%
import numpy as np
import pandas as pd

# %%
DATA_PATH = '../data/train_data.csv'
dtype = {
    'userID': 'int16',
    'answerCode': 'int8',
    'KnowledgeTag': 'int16'
}

data = pd.read_csv(DATA_PATH, dtype=dtype, parse_dates=['Timestamp'])
data = data.sort_values(by=['userID', 'Timestamp']).reset_index(drop=True)
data
# Out:
#          userID assessmentItemID      testId  answerCode           Timestamp  \
# 0             0       A060001001  A060000001           1 2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1 2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1 2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1 2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1 2020-03-24 00:17:36
# ...         ...              ...         ...         ...                 ...
# 2266581    7441       A030071005  A030000071           0 2020-06-05 06:50:21
# 2266582    7441       A040165001  A040000165           1 2020-08-21 01:06:39
# 2266583    7441       A040165002  A040000165           1 2020-08-21 01:06:50
# 2266584    7441       A040165003  A040000165           1 2020-08-21 01:07:36
# 2266585    7441       A040165004  A040000165           1 2020-08-21 01:08:49
#
#          KnowledgeTag
# 0                7224
# 1                7225
# 2                7225
# 3                7225
# 4                7225
# ...               ...
# 2266581           438
# 2266582          8836
# 2266583          8836
# 2266584          8836
# 2266585          8836
#
# [2266586 rows x 6 columns]

# %%
df = data.copy()

# %%
df['question'] = df['assessmentItemID'].apply(lambda x: x[1:])
df['testID'] = df['assessmentItemID'].apply(lambda x: x[1:7])
df['testID1'] = df['assessmentItemID'].apply(lambda x: x[1:4])
df['testID2'] = df['assessmentItemID'].apply(lambda x: x[4:7])
df['testNum'] = df['assessmentItemID'].apply(lambda x: x[7:])
df['KnowledgeTag'] = df['KnowledgeTag'].astype('str')
df['Time'] = (df.groupby(['userID','testID'])['Timestamp'].shift(-1) - df['Timestamp']).apply(lambda x: x.seconds)
df['Time'] = df['Time'].ffill().astype('int')
df = df[['userID','question','testID','testID1','testID2','testNum','KnowledgeTag','Timestamp','Time','answerCode']]
df
# Out:
#          userID   question  testID testID1 testID2 testNum KnowledgeTag  \
# 0             0  060001001  060001     060     001     001         7224
# 1             0  060001002  060001     060     001     002         7225
# 2             0  060001003  060001     060     001     003         7225
# 3             0  060001004  060001     060     001     004         7225
# 4             0  060001005  060001     060     001     005         7225
# ...         ...        ...     ...     ...     ...     ...          ...
# 2266581    7441  030071005  030071     030     071     005          438
# 2266582    7441  040165001  040165     040     165     001         8836
# 2266583    7441  040165002  040165     040     165     002         8836
# 2266584    7441  040165003  040165     040     165     003         8836
# 2266585    7441  040165004  040165     040     165     004         8836
#
#                   Timestamp  Time  answerCode
# 0       2020-03-24 00:17:11     3           1
# 1       2020-03-24 00:17:14     8           1
# 2       2020-03-24 00:17:22     7           1
# 3       2020-03-24 00:17:29     7           1
# 4       2020-03-24 00:17:36    11           1
# ...                     ...   ...         ...
# 2266581 2020-06-05 06:50:21    24           0
# 2266582 2020-08-21 01:06:39    11           1
# 2266583 2020-08-21 01:06:50    46           1
# 2266584 2020-08-21 01:07:36    73           1
# 2266585 2020-08-21 01:08:49    73           1
#
# [2266586 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2266586 entries, 0 to 2266585
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   userID        int16
#  1   testID        object
#  2   testID1       object
#  3   testID2       object
#  4   testNum       object
#  5   KnowledgeTag  object
#  6   Timestamp     datetime64[ns]
#  7   Time          int64
#  8   answerCode    int8
# dtypes: datetime64[ns](1), int16(1), int64(1), int8(1), object(5)
# memory usage: 127.5+ MB

# %%
df.isnull().sum()
# Out:
# userID          0
# testID          0
# testID1         0
# testID2         0
# testNum         0
# KnowledgeTag    0
# Timestamp       0
# Time            0
# answerCode      0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### shift

# %%
df['Time_s1'] = df.groupby(['userID','testID'])['Time'].shift(1)
df['Time_s2'] = df.groupby(['userID','testID'])['Time'].shift(2)
df['Time_s3'] = df.groupby(['userID','testID'])['Time'].shift(3)
# df['Time_s4'] = df.groupby(['userID','testID'])['Time'].shift(4)
# df['Time_s5'] = df.groupby(['userID','testID'])['Time'].shift(5)

df['answer_s1'] = df.groupby(['userID','testID'])['answerCode'].shift(1)
df['answer_s2'] = df.groupby(['userID','testID'])['answerCode'].shift(2)
df['answer_s3'] = df.groupby(['userID','testID'])['answerCode'].shift(3)
# df['answer_s4'] = df.groupby(['userID','testID'])['answerCode'].shift(4)
# df['answer_s5'] = df.groupby(['userID','testID'])['answerCode'].shift(5)

# %%
print(len(df))
df.isnull().sum()
# Out:
# 2266586
# userID                0
# testID                0
# testID1               0
# testID2               0
# testNum               0
# KnowledgeTag          0
# Timestamp             0
# Time                  0
# answerCode            0
# Time_s1          365164
# Time_s2          730328
# Time_s3         1095233
# Time_s4         1458558
# Time_s5         1809606
# answer_s1        365164
# answer_s2        730328
# answer_s3       1095233
# answer_s4       1458558
# answer_s5       1809606
# dtype: int64

# %% [markdown]
# ### 이동 평균

# %%
df['rolling_Time'] = df.groupby(['userID'])['Time'].rolling(3).mean().values
df['rolling_correct'] = df.groupby(['userID'])['answerCode'].rolling(3).mean().values
df
# Out:
#          userID   question  testID testID1 testID2 testNum KnowledgeTag  \
# 0             0  060001001  060001     060     001     001         7224
# 1             0  060001002  060001     060     001     002         7225
# 2             0  060001003  060001     060     001     003         7225
# 3             0  060001004  060001     060     001     004         7225
# 4             0  060001005  060001     060     001     005         7225
# ...         ...        ...     ...     ...     ...     ...          ...
# 2266581    7441  030071005  030071     030     071     005          438
# 2266582    7441  040165001  040165     040     165     001         8836
# 2266583    7441  040165002  040165     040     165     002         8836
# 2266584    7441  040165003  040165     040     165     003         8836
# 2266585    7441  040165004  040165     040     165     004         8836
#
#                   Timestamp  Time  answerCode  Time_s1  Time_s2  Time_s3  \
# 0       2020-03-24 00:17:11     3           1      NaN      NaN      NaN
# 1       2020-03-24 00:17:14     8           1      3.0      NaN      NaN
# 2       2020-03-24 00:17:22     7           1      8.0      3.0      NaN
# 3       2020-03-24 00:17:29     7           1      7.0      8.0      3.0
# 4       2020-03-24 00:17:36    11           1      7.0      7.0      8.0
# ...                     ...   ...         ...      ...      ...      ...
# 2266581 2020-06-05 06:50:21    24           0     24.0     34.0     40.0
# 2266582 2020-08-21 01:06:39    11           1      NaN      NaN      NaN
# 2266583 2020-08-21 01:06:50    46           1     11.0      NaN      NaN
# 2266584 2020-08-21 01:07:36    73           1     46.0     11.0      NaN
# 2266585 2020-08-21 01:08:49    73           1     73.0     46.0     11.0
#
#          answer_s1  answer_s2  answer_s3  rolling_Time  rolling_correct
# 0              NaN        NaN        NaN           NaN              NaN
# 1              1.0        NaN        NaN           NaN              NaN
# 2              1.0        1.0        NaN      6.000000         1.000000
# 3              1.0        1.0        1.0      7.333333         1.000000
# 4              1.0        1.0        1.0      8.333333         1.000000
# ...            ...        ...        ...           ...              ...
# 2266581        0.0        1.0        0.0     27.333333         0.333333
# 2266582        NaN        NaN        NaN     19.666667         0.333333
# 2266583        1.0        NaN        NaN     27.000000         0.666667
# 2266584        1.0        1.0        NaN     43.333333         1.000000
# 2266585        1.0        1.0        1.0     64.000000         1.000000
#
# [2266586 rows x 18 columns]

# %% [markdown]
# ### 누적합 : User 별 문제 수 / 정답 수 / 정답률

# %%
# 문제 수
df[f'user_past_count'] = df.groupby('userID').cumcount()
# 정답 수
df['shift'] = df.groupby('userID')['answerCode'].shift().fillna(0)
df[f'user_past_correct'] = df.groupby('userID')['shift'].cumsum()
df = df.drop('shift', axis=1)
# 정답률
df[f'user_past_average_correct'] = (df[f'user_past_correct'] / df[f'user_past_count']).fillna(0)
df
# Out:
#          userID   question  testID testID1 testID2 testNum KnowledgeTag  \
# 0             0  060001001  060001     060     001     001         7224
# 1             0  060001002  060001     060     001     002         7225
# 2             0  060001003  060001     060     001     003         7225
# 3             0  060001004  060001     060     001     004         7225
# 4             0  060001005  060001     060     001     005         7225
# ...         ...        ...     ...     ...     ...     ...          ...
# 2266581    7441  030071005  030071     030     071     005          438
# 2266582    7441  040165001  040165     040     165     001         8836
# 2266583    7441  040165002  040165     040     165     002         8836
# 2266584    7441  040165003  040165     040     165     003         8836
# 2266585    7441  040165004  040165     040     165     004         8836
#
#                   Timestamp  Time  answerCode  ...  Time_s2  Time_s3  \
# 0       2020-03-24 00:17:11     3           1  ...      NaN      NaN
# 1       2020-03-24 00:17:14     8           1  ...      NaN      NaN
# 2       2020-03-24 00:17:22     7           1  ...      3.0      NaN
# 3       2020-03-24 00:17:29     7           1  ...      8.0      3.0
# 4       2020-03-24 00:17:36    11           1  ...      7.0      8.0
# ...                     ...   ...         ...  ...      ...      ...
# 2266581 2020-06-05 06:50:21    24           0  ...     34.0     40.0
# 2266582 2020-08-21 01:06:39    11           1  ...      NaN      NaN
# 2266583 2020-08-21 01:06:50    46           1  ...      NaN      NaN
# 2266584 2020-08-21 01:07:36    73           1  ...     11.0      NaN
# 2266585 2020-08-21 01:08:49    73           1  ...     46.0     11.0
#
#          answer_s1  answer_s2  answer_s3  rolling_Time  rolling_correct  \
# 0              NaN        NaN        NaN           NaN              NaN
# 1              1.0        NaN        NaN           NaN              NaN
# 2              1.0        1.0        NaN      6.000000         1.000000
# 3              1.0        1.0        1.0      7.333333         1.000000
# 4              1.0        1.0        1.0      8.333333         1.000000
# ...            ...        ...        ...           ...              ...
# 2266581        0.0        1.0        0.0     27.333333         0.333333
# 2266582        NaN        NaN        NaN     19.666667         0.333333
# 2266583        1.0        NaN        NaN     27.000000         0.666667
# 2266584        1.0        1.0        NaN     43.333333         1.000000
# 2266585        1.0        1.0        1.0     64.000000         1.000000
#
#          user_past_count  user_past_correct  user_past_average_correct
# 0                      0                0.0                   0.000000
# 1                      1                1.0                   1.000000
# 2                      2                2.0                   1.000000
# 3                      3                3.0                   1.000000
# 4                      4                4.0                   1.000000
# ...                  ...                ...                        ...
# 2266581                4                1.0                   0.250000
# 2266582                5                1.0                   0.200000
# 2266583                6                2.0                   0.333333
# 2266584                7                3.0                   0.428571
# 2266585                8                4.0                   0.500000
#
# [2266586 rows x 21 columns]

# %% [markdown]
# ### 누적합 : Feature 별 문제 수 / 정답 수 / 정답률

# %%
feature_list = ['question','testID','testID1','testID2','testNum','KnowledgeTag']
for feature in feature_list:
    # 문제 수
    df[f'{feature}_past_count'] = df.groupby(feature).cumcount()
    # 정답 수
    df['shift'] = df.groupby(feature)['answerCode'].shift().fillna(0)
    df[f'{feature}_past_correct'] = df.groupby(feature)['shift'].cumsum()
    df = df.drop('shift', axis=1)
    # 정답률
    df[f'{feature}_past_average_correct'] = (df[f'{feature}_past_correct'] / df[f'{feature}_past_count']).fillna(0)
df
# Out:
#          userID   question  testID testID1 testID2 testNum KnowledgeTag  \
# 0             0  060001001  060001     060     001     001         7224
# 1             0  060001002  060001     060     001     002         7225
# 2             0  060001003  060001     060     001     003         7225
# 3             0  060001004  060001     060     001     004         7225
# 4             0  060001005  060001     060     001     005         7225
# ...         ...        ...     ...     ...     ...     ...          ...
# 2266581    7441  030071005  030071     030     071     005          438
# 2266582    7441  040165001  040165     040     165     001         8836
# 2266583    7441  040165002  040165     040     165     002         8836
# 2266584    7441  040165003  040165     040     165     003         8836
# 2266585    7441  040165004  040165     040     165     004         8836
#
#                   Timestamp  Time  answerCode  ...  \
# 0       2020-03-24 00:17:11     3           1  ...
# 1       2020-03-24 00:17:14     8           1  ...
# 2       2020-03-24 00:17:22     7           1  ...
# 3       2020-03-24 00:17:29     7           1  ...
# 4       2020-03-24 00:17:36    11           1  ...
# ...                     ...   ...         ...  ...
# 2266581 2020-06-05 06:50:21    24           0  ...
# 2266582 2020-08-21 01:06:39    11           1  ...
# 2266583 2020-08-21 01:06:50    46           1  ...
# 2266584 2020-08-21 01:07:36    73           1  ...
# 2266585 2020-08-21 01:08:49    73           1  ...
#
#          testID1_past_average_correct  testID2_past_count  \
# 0                            0.000000                   0
# 1                            1.000000                   1
# 2                            1.000000                   2
# 3                            1.000000                   3
# 4                            1.000000                   4
# ...                               ...                 ...
# 2266581                      0.702240               13697
# 2266582                      0.684052                7542
# 2266583                      0.684053                7543
# 2266584                      0.684054                7544
# 2266585                      0.684055                7545
#
#          testID2_past_correct  testID2_past_average_correct  \
# 0                         0.0                      0.000000
# 1                         1.0                      1.000000
# 2                         2.0                      1.000000
# 3                         3.0                      1.000000
# 4                         4.0                      1.000000
# ...                       ...                           ...
# 2266581                8751.0                      0.638899
# 2266582                5359.0                      0.710554
# 2266583                5360.0                      0.710593
# 2266584                5361.0                      0.710631
# 2266585                5362.0                      0.710669
#
#          testNum_past_count  testNum_past_correct  \
# 0                         0                   0.0
# 1                         0                   0.0
# 2                         0                   0.0
# 3                         0                   0.0
# 4                         0                   0.0
# ...                     ...                   ...
# 2266581              360606              216052.0
# 2266582              371754              278784.0
# 2266583              370971              267122.0
# 2266584              371639              255603.0
# 2266585              369704              245248.0
#
#          testNum_past_average_correct  KnowledgeTag_past_count  \
# 0                            0.000000                        0
# 1                            0.000000                        0
# 2                            0.000000                        1
# 3                            0.000000                        2
# 4                            0.000000                        3
# ...                               ...                      ...
# 2266581                      0.599136                     4079
# 2266582                      0.749915                     3147
# 2266583                      0.720062                     3148
# 2266584                      0.687772                     3149
# 2266585                      0.663363                     3150
#
#          KnowledgeTag_past_correct  KnowledgeTag_past_average_correct
# 0                              0.0                           0.000000
# 1                              0.0                           0.000000
# 2                              1.0                           1.000000
# 3                              2.0                           1.000000
# 4                              3.0                           1.000000
# ...                            ...                                ...
# 2266581                     2814.0                           0.689875
# 2266582                     2195.0                           0.697490
# 2266583                     2196.0                           0.697586
# 2266584                     2197.0                           0.697682
# 2266585                     2198.0                           0.697778
#
# [2266586 rows x 39 columns]

# %% [markdown]
# ### 누적합 : User & Feature 별 문제 수 / 정답 수 / 정답률

# %%
feature_list = ['question','testID','testID1','testID2','testNum','KnowledgeTag']
for feature in feature_list:
    # 문제 수
    df[f'user_{feature}_past_count'] = df.groupby(['userID',feature]).cumcount()
    # 정답 수
    df['shift'] = df.groupby(['userID',feature])['answerCode'].shift().fillna(0)
    df[f'user_{feature}_past_correct'] = df.groupby(['userID',feature])['shift'].cumsum()
    df = df.drop('shift', axis=1)
    # 정답률
    df[f'user_{feature}_past_average_correct'] = (df[f'user_{feature}_past_correct'] / df[f'user_{feature}_past_count']).fillna(0)
df
# Out:
#          userID   question  testID testID1 testID2 testNum KnowledgeTag  \
# 0             0  060001001  060001     060     001     001         7224
# 1             0  060001002  060001     060     001     002         7225
# 2             0  060001003  060001     060     001     003         7225
# 3             0  060001004  060001     060     001     004         7225
# 4             0  060001005  060001     060     001     005         7225
# ...         ...        ...     ...     ...     ...     ...          ...
# 2266581    7441  030071005  030071     030     071     005          438
# 2266582    7441  040165001  040165     040     165     001         8836
# 2266583    7441  040165002  040165     040     165     002         8836
# 2266584    7441  040165003  040165     040     165     003         8836
# 2266585    7441  040165004  040165     040     165     004         8836
#
#                   Timestamp  Time  answerCode  ...  \
# 0       2020-03-24 00:17:11     3           1  ...
# 1       2020-03-24 00:17:14     8           1  ...
# 2       2020-03-24 00:17:22     7           1  ...
# 3       2020-03-24 00:17:29     7           1  ...
# 4       2020-03-24 00:17:36    11           1  ...
# ...                     ...   ...         ...  ...
# 2266581 2020-06-05 06:50:21    24           0  ...
# 2266582 2020-08-21 01:06:39    11           1  ...
# 2266583 2020-08-21 01:06:50    46           1  ...
# 2266584 2020-08-21 01:07:36    73           1  ...
# 2266585 2020-08-21 01:08:49    73           1  ...
#
#          user_testID1_past_average_correct  user_testID2_past_count  \
# 0                                     0.00                        0
# 1                                     1.00                        1
# 2                                     1.00                        2
# 3                                     1.00                        3
# 4                                     1.00                        4
# ...                                    ...                      ...
# 2266581                               0.25                        4
# 2266582                               0.00                        0
# 2266583                               1.00                        1
# 2266584                               1.00                        2
# 2266585                               1.00                        3
#
#          user_testID2_past_correct  user_testID2_past_average_correct  \
# 0                              0.0                               0.00
# 1                              1.0                               1.00
# 2                              2.0                               1.00
# 3                              3.0                               1.00
# 4                              4.0                               1.00
# ...                            ...                                ...
# 2266581                        1.0                               0.25
# 2266582                        0.0                               0.00
# 2266583                        1.0                               1.00
# 2266584                        2.0                               1.00
# 2266585                        3.0                               1.00
#
#          user_testNum_past_count  user_testNum_past_correct  \
# 0                              0                        0.0
# 1                              0                        0.0
# 2                              0                        0.0
# 3                              0                        0.0
# 4                              0                        0.0
# ...                          ...                        ...
# 2266581                        0                        0.0
# 2266582                        1                        0.0
# 2266583                        1                        0.0
# 2266584                        1                        1.0
# 2266585                        1                        0.0
#
#          user_testNum_past_average_correct  user_KnowledgeTag_past_count  \
# 0                                      0.0                             0
# 1                                      0.0                             0
# 2                                      0.0                             1
# 3                                      0.0                             2
# 4                                      0.0                             3
# ...                                    ...                           ...
# 2266581                                0.0                             4
# 2266582                                0.0                             0
# 2266583                                0.0                             1
# 2266584                                1.0                             2
# 2266585                                0.0                             3
#
#          user_KnowledgeTag_past_correct  \
# 0                                   0.0
# 1                                   0.0
# 2                                   1.0
# 3                                   2.0
# 4                                   3.0
# ...                                 ...
# 2266581                             1.0
# 2266582                             0.0
# 2266583                             1.0
# 2266584                             2.0
# 2266585                             3.0
#
#          user_KnowledgeTag_past_average_correct
# 0                                          0.00
# 1                                          0.00
# 2                                          1.00
# 3                                          1.00
# 4                                          1.00
# ...                                         ...
# 2266581                                    0.25
# 2266582                                    0.00
# 2266583                                    1.00
# 2266584                                    1.00
# 2266585                                    1.00
#
# [2266586 rows x 57 columns]

# %% [markdown]
# ### 상관계수

# %%
print(len(df.columns))
df.columns
# Out:
# 57
# Index(['userID', 'question', 'testID', 'testID1', 'testID2', 'testNum',
#        'KnowledgeTag', 'Timestamp', 'Time', 'answerCode', 'Time_s1', 'Time_s2',
#        'Time_s3', 'answer_s1', 'answer_s2', 'answer_s3', 'rolling_Time',
#        'rolling_correct', 'user_past_count', 'user_past_correct',
#        'user_past_average_correct', 'question_past_count',
#        'question_past_correct', 'question_past_average_correct',
#        'testID_past_count', 'testID_past_correct',
#        'testID_past_average_correct', 'testID1_past_count',
#        'testID1_past_correct', 'testID1_past_average_correct',
#        'testID2_past_count', 'testID2_past_correct',
#        'testID2_past_average_correct', 'testNum_past_count',
#        'testNum_past_correct', 'testNum_past_average_correct',
#        'KnowledgeTag_past_count', 'KnowledgeTag_past_correct',
#        'KnowledgeTag_past_average_correct', 'user_question_past_count',
#        'user_question_past_correct', 'user_question_past_average_correct',
#        'user_testID_past_count', 'user_testID_past_correct',
#        'user_testID_past_average_correct', 'user_testID1_past_count',
#        'user_testID1_past_correct', 'user_testID1_past_average_correct',
#        'user_testID2_past_count', 'user_testID2_past_correct',
#        'user_testID2_past_average_correct', 'user_testNum_past_count',
#        'user_testNum_past_correct', 'user_testNum_past_average_correct',
#        'user_KnowledgeTag_past_count', 'user_KnowledgeTag_past_correct',
#        'user_KnowledgeTag_past_average_correct'],
#       dtype='object')

# %%
df[['answerCode', 'userID', 'question', 'testID', 'testID1', 'testID2',
    'testNum', 'KnowledgeTag', 'Timestamp', 'Time']].corr()
# Out:
#               answerCode    userID  question    testID   testID1   testID2  \
# answerCode      1.000000 -0.035235 -0.201803 -0.201803 -0.201841  0.058700
# userID         -0.035235  1.000000 -0.065527 -0.065527 -0.065891  0.179791
# question       -0.201803 -0.065527  1.000000  1.000000  0.999998 -0.204635
# testID         -0.201803 -0.065527  1.000000  1.000000  0.999998 -0.204635
# testID1        -0.201841 -0.065891  0.999998  0.999998  1.000000 -0.206732
# testID2         0.058700  0.179791 -0.204635 -0.204635 -0.206732  1.000000
# testNum        -0.165713 -0.021852  0.236795  0.236795  0.236791 -0.046904
# KnowledgeTag    0.012086 -0.015064 -0.150523 -0.150523 -0.150631  0.080247
# Timestamp      -0.036482  0.126468  0.044949  0.044949  0.043472  0.664978
# Time           -0.000902 -0.016541  0.000802  0.000802  0.000809 -0.003525
#
#                testNum  KnowledgeTag  Timestamp      Time
# answerCode   -0.165713      0.012086  -0.036482 -0.000902
# userID       -0.021852     -0.015064   0.126468 -0.016541
# question      0.236795     -0.150523   0.044949  0.000802
# testID        0.236795     -0.150523   0.044949  0.000802
# testID1       0.236791     -0.150631   0.043472  0.000809
# testID2      -0.046904      0.080247   0.664978 -0.003525
# testNum       1.000000      0.012776   0.010575  0.048217
# KnowledgeTag  0.012776      1.000000   0.130494  0.000038
# Timestamp     0.010575      0.130494   1.000000 -0.015716
# Time          0.048217      0.000038  -0.015716  1.000000

# %%
df[['answerCode','Time_s1', 'Time_s2', 'Time_s3',
    'answer_s1', 'answer_s2', 'answer_s3', 'rolling_Time', 'rolling_correct',
    'user_past_count', 'user_past_correct', 'user_past_average_correct']].corr()
# Out:
#                            answerCode   Time_s1   Time_s2   Time_s3  \
# answerCode                   1.000000  0.013902  0.012093  0.013409
# Time_s1                      0.013902  1.000000  0.001249 -0.002164
# Time_s2                      0.012093  0.001249  1.000000 -0.000135
# Time_s3                      0.013409 -0.002164 -0.000135  1.000000
# answer_s1                    0.367876 -0.003971  0.012418  0.010550
# answer_s2                    0.343081  0.000916 -0.007025  0.012410
# answer_s3                    0.324096  0.004059 -0.000761 -0.009621
# rolling_Time                 0.012775  0.169914  0.197306  0.001230
# rolling_correct              0.724547  0.003212  0.006231  0.016032
# user_past_count              0.012336  0.029408  0.032450  0.036474
# user_past_correct            0.079323  0.030857  0.034029  0.038311
# user_past_average_correct    0.290078  0.011088  0.012107  0.014085
#
#                            answer_s1  answer_s2  answer_s3  rolling_Time  \
# answerCode                  0.367876   0.343081   0.324096      0.012775
# Time_s1                    -0.003971   0.000916   0.004059      0.169914
# Time_s2                     0.012418  -0.007025  -0.000761      0.197306
# Time_s3                     0.010550   0.012410  -0.009621      0.001230
# answer_s1                   1.000000   0.374130   0.350807      0.011397
# answer_s2                   0.374130   1.000000   0.379971      0.008645
# answer_s3                   0.350807   0.379971   1.000000      0.012330
# rolling_Time                0.011397   0.008645   0.012330      1.000000
# rolling_correct             0.751686   0.743960   0.462428      0.012375
# user_past_count             0.012500   0.010222   0.009319      0.003867
# user_past_correct           0.084159   0.085053   0.087166      0.008153
# user_past_average_correct   0.341927   0.350382   0.358018      0.020916
#
#                            rolling_correct  user_past_count  \
# answerCode                        0.724547         0.012336
# Time_s1                           0.003212         0.029408
# Time_s2                           0.006231         0.032450
# Time_s3                           0.016032         0.036474
# answer_s1                         0.751686         0.012500
# answer_s2                         0.743960         0.010222
# answer_s3                         0.462428         0.009319
# rolling_Time                      0.012375         0.003867
# rolling_correct                   1.000000         0.017487
# user_past_count                   0.017487         1.000000
# user_past_correct                 0.111642         0.952046
# user_past_average_correct         0.439339         0.085161
#
#                            user_past_correct  user_past_average_correct
# answerCode                          0.079323                   0.290078
# Time_s1                             0.030857                   0.011088
# Time_s2                             0.034029                   0.012107
# Time_s3                             0.038311                   0.014085
# answer_s1                           0.084159                   0.341927
# answer_s2                           0.085053                   0.350382
# answer_s3                           0.087166                   0.358018
# rolling_Time                        0.008153                   0.020916
# rolling_correct                     0.111642                   0.439339
# user_past_count                     0.952046                   0.085161
# user_past_correct                   1.000000                   0.280054
# user_past_average_correct           0.280054                   1.000000

# %%
df[['answerCode', 
    'question_past_count', 'question_past_correct', 'question_past_average_correct',
    'testID_past_count', 'testID_past_correct', 'testID_past_average_correct',
    'testID1_past_count', 'testID1_past_correct', 'testID1_past_average_correct',
    'testID2_past_count', 'testID2_past_correct', 'testID2_past_average_correct',
    'testNum_past_count', 'testNum_past_correct', 'testNum_past_average_correct',
    'KnowledgeTag_past_count', 'KnowledgeTag_past_correct', 'KnowledgeTag_past_average_correct',]].corr()
# Out:
#                                    answerCode  question_past_count  \
# answerCode                           1.000000            -0.059749
# question_past_count                 -0.059749             1.000000
# question_past_correct                0.119692             0.865180
# question_past_average_correct        0.377333            -0.038786
# testID_past_count                   -0.107166             0.914466
# testID_past_correct                 -0.004687             0.904425
# testID_past_average_correct          0.294803            -0.085568
# testID1_past_count                  -0.022178             0.815037
# testID1_past_correct                 0.029185             0.769920
# testID1_past_average_correct         0.223380            -0.073303
# testID2_past_count                  -0.071605             0.875508
# testID2_past_correct                -0.057767             0.883914
# testID2_past_average_correct         0.122733            -0.137408
# testNum_past_count                   0.028425             0.765014
# testNum_past_correct                 0.046287             0.733077
# testNum_past_average_correct         0.170441            -0.042813
# KnowledgeTag_past_count              0.014195             0.693722
# KnowledgeTag_past_correct            0.075194             0.635031
# KnowledgeTag_past_average_correct    0.284245            -0.060619
#
#                                    question_past_correct  \
# answerCode                                      0.119692
# question_past_count                             0.865180
# question_past_correct                           1.000000
# question_past_average_correct                   0.367724
# testID_past_count                               0.714780
# testID_past_correct                             0.861477
# testID_past_average_correct                     0.235334
# testID1_past_count                              0.780214
# testID1_past_correct                            0.807365
# testID1_past_average_correct                    0.182329
# testID2_past_count                              0.749638
# testID2_past_correct                            0.778468
# testID2_past_average_correct                   -0.000388
# testNum_past_count                              0.780073
# testNum_past_correct                            0.771622
# testNum_past_average_correct                    0.129023
# KnowledgeTag_past_count                         0.691798
# KnowledgeTag_past_correct                       0.722385
# KnowledgeTag_past_average_correct               0.246353
#
#                                    question_past_average_correct  \
# answerCode                                              0.377333
# question_past_count                                    -0.038786
# question_past_correct                                   0.367724
# question_past_average_correct                           1.000000
# testID_past_count                                      -0.145777
# testID_past_correct                                     0.089520
# testID_past_average_correct                             0.688588
# testID1_past_count                                      0.066702
# testID1_past_correct                                    0.169209
# testID1_past_average_correct                            0.482760
# testID2_past_count                                     -0.062438
# testID2_past_correct                                   -0.028354
# testID2_past_average_correct                            0.273489
# testNum_past_count                                      0.156082
# testNum_past_correct                                    0.191154
# testNum_past_average_correct                            0.369706
# KnowledgeTag_past_count                                 0.099285
# KnowledgeTag_past_correct                               0.229154
# KnowledgeTag_past_average_correct                       0.650315
#
#                                    testID_past_count  testID_past_correct  \
# answerCode                                 -0.107166            -0.004687
# question_past_count                         0.914466             0.904425
# question_past_correct                       0.714780             0.861477
# question_past_average_correct              -0.145777             0.089520
# testID_past_count                           1.000000             0.913586
# testID_past_correct                         0.913586             1.000000
# testID_past_average_correct                -0.232492             0.098226
# testID1_past_count                          0.725188             0.805959
# testID1_past_correct                        0.616182             0.768922
# testID1_past_average_correct               -0.289278            -0.021405
# testID2_past_count                          0.821174             0.808019
# testID2_past_correct                        0.823430             0.834853
# testID2_past_average_correct               -0.163301            -0.028498
# testNum_past_count                          0.591159             0.673883
# testNum_past_correct                        0.555284             0.639388
# testNum_past_average_correct               -0.171949            -0.117162
# KnowledgeTag_past_count                     0.566077             0.661681
# KnowledgeTag_past_correct                   0.469219             0.648688
# KnowledgeTag_past_average_correct          -0.213881             0.088251
#
#                                    testID_past_average_correct  \
# answerCode                                            0.294803
# question_past_count                                  -0.085568
# question_past_correct                                 0.235334
# question_past_average_correct                         0.688588
# testID_past_count                                    -0.232492
# testID_past_correct                                   0.098226
# testID_past_average_correct                           1.000000
# testID1_past_count                                    0.061596
# testID1_past_correct                                  0.207686
# testID1_past_average_correct                          0.684915
# testID2_past_count                                   -0.118773
# testID2_past_correct                                 -0.071662
# testID2_past_average_correct                          0.407681
# testNum_past_count                                    0.092914
# testNum_past_correct                                  0.100067
# testNum_past_average_correct                          0.155920
# KnowledgeTag_past_count                               0.119589
# KnowledgeTag_past_correct                             0.298315
# KnowledgeTag_past_average_correct                     0.866068
#
#                                    testID1_past_count  testID1_past_correct  \
# answerCode                                  -0.022178              0.029185
# question_past_count                          0.815037              0.769920
# question_past_correct                        0.780214              0.807365
# question_past_average_correct                0.066702              0.169209
# testID_past_count                            0.725188              0.616182
# testID_past_correct                          0.805959              0.768922
# testID_past_average_correct                  0.061596              0.207686
# testID1_past_count                           1.000000              0.965796
# testID1_past_correct                         0.965796              1.000000
# testID1_past_average_correct                 0.065856              0.281469
# testID2_past_count                           0.779553              0.716036
# testID2_past_correct                         0.812202              0.752153
# testID2_past_average_correct                 0.045994              0.081825
# testNum_past_count                           0.847025              0.851107
# testNum_past_correct                         0.811436              0.820239
# testNum_past_average_correct                -0.049709              0.009473
# KnowledgeTag_past_count                      0.657778              0.693233
# KnowledgeTag_past_correct                    0.634255              0.712152
# KnowledgeTag_past_average_correct            0.061253              0.218575
#
#                                    testID1_past_average_correct  \
# answerCode                                             0.223380
# question_past_count                                   -0.073303
# question_past_correct                                  0.182329
# question_past_average_correct                          0.482760
# testID_past_count                                     -0.289278
# testID_past_correct                                   -0.021405
# testID_past_average_correct                            0.684915
# testID1_past_count                                     0.065856
# testID1_past_correct                                   0.281469
# testID1_past_average_correct                           1.000000
# testID2_past_count                                    -0.124903
# testID2_past_correct                                  -0.106353
# testID2_past_average_correct                           0.177602
# testNum_past_count                                     0.116564
# testNum_past_correct                                   0.127846
# testNum_past_average_correct                           0.236643
# KnowledgeTag_past_count                                0.188867
# KnowledgeTag_past_correct                              0.339401
# KnowledgeTag_past_average_correct                      0.732196
#
#                                    testID2_past_count  testID2_past_correct  \
# answerCode                                  -0.071605             -0.057767
# question_past_count                          0.875508              0.883914
# question_past_correct                        0.749638              0.778468
# question_past_average_correct               -0.062438             -0.028354
# testID_past_count                            0.821174              0.823430
# testID_past_correct                          0.808019              0.834853
# testID_past_average_correct                 -0.118773             -0.071662
# testID1_past_count                           0.779553              0.812202
# testID1_past_correct                         0.716036              0.752153
# testID1_past_average_correct                -0.124903             -0.106353
# testID2_past_count                           1.000000              0.988654
# testID2_past_correct                         0.988654              1.000000
# testID2_past_average_correct                -0.295696             -0.180749
# testNum_past_count                           0.714859              0.743131
# testNum_past_correct                         0.682835              0.710117
# testNum_past_average_correct                -0.064416             -0.062676
# KnowledgeTag_past_count                      0.679651              0.687884
# KnowledgeTag_past_correct                    0.607072              0.625907
# KnowledgeTag_past_average_correct           -0.116644             -0.078263
#
#                                    testID2_past_average_correct  \
# answerCode                                             0.122733
# question_past_count                                   -0.137408
# question_past_correct                                 -0.000388
# question_past_average_correct                          0.273489
# testID_past_count                                     -0.163301
# testID_past_correct                                   -0.028498
# testID_past_average_correct                            0.407681
# testID1_past_count                                     0.045994
# testID1_past_correct                                   0.081825
# testID1_past_average_correct                           0.177602
# testID2_past_count                                    -0.295696
# testID2_past_correct                                  -0.180749
# testID2_past_average_correct                           1.000000
# testNum_past_count                                     0.041516
# testNum_past_correct                                   0.042059
# testNum_past_average_correct                           0.037228
# KnowledgeTag_past_count                               -0.104378
# KnowledgeTag_past_correct                             -0.031093
# KnowledgeTag_past_average_correct                      0.341299
#
#                                    testNum_past_count  testNum_past_correct  \
# answerCode                                   0.028425              0.046287
# question_past_count                          0.765014              0.733077
# question_past_correct                        0.780073              0.771622
# question_past_average_correct                0.156082              0.191154
# testID_past_count                            0.591159              0.555284
# testID_past_correct                          0.673883              0.639388
# testID_past_average_correct                  0.092914              0.100067
# testID1_past_count                           0.847025              0.811436
# testID1_past_correct                         0.851107              0.820239
# testID1_past_average_correct                 0.116564              0.127846
# testID2_past_count                           0.714859              0.682835
# testID2_past_correct                         0.743131              0.710117
# testID2_past_average_correct                 0.041516              0.042059
# testNum_past_count                           1.000000              0.990070
# testNum_past_correct                         0.990070              1.000000
# testNum_past_average_correct                 0.301804              0.398078
# KnowledgeTag_past_count                      0.626976              0.603346
# KnowledgeTag_past_correct                    0.614479              0.595272
# KnowledgeTag_past_average_correct            0.108706              0.119987
#
#                                    testNum_past_average_correct  \
# answerCode                                             0.170441
# question_past_count                                   -0.042813
# question_past_correct                                  0.129023
# question_past_average_correct                          0.369706
# testID_past_count                                     -0.171949
# testID_past_correct                                   -0.117162
# testID_past_average_correct                            0.155920
# testID1_past_count                                    -0.049709
# testID1_past_correct                                   0.009473
# testID1_past_average_correct                           0.236643
# testID2_past_count                                    -0.064416
# testID2_past_correct                                  -0.062676
# testID2_past_average_correct                           0.037228
# testNum_past_count                                     0.301804
# testNum_past_correct                                   0.398078
# testNum_past_average_correct                           1.000000
# KnowledgeTag_past_count                                0.002200
# KnowledgeTag_past_correct                              0.046489
# KnowledgeTag_past_average_correct                      0.208066
#
#                                    KnowledgeTag_past_count  \
# answerCode                                        0.014195
# question_past_count                               0.693722
# question_past_correct                             0.691798
# question_past_average_correct                     0.099285
# testID_past_count                                 0.566077
# testID_past_correct                               0.661681
# testID_past_average_correct                       0.119589
# testID1_past_count                                0.657778
# testID1_past_correct                              0.693233
# testID1_past_average_correct                      0.188867
# testID2_past_count                                0.679651
# testID2_past_correct                              0.687884
# testID2_past_average_correct                     -0.104378
# testNum_past_count                                0.626976
# testNum_past_correct                              0.603346
# testNum_past_average_correct                      0.002200
# KnowledgeTag_past_count                           1.000000
# KnowledgeTag_past_correct                         0.959742
# KnowledgeTag_past_average_correct                 0.121748
#
#                                    KnowledgeTag_past_correct  \
# answerCode                                          0.075194
# question_past_count                                 0.635031
# question_past_correct                               0.722385
# question_past_average_correct                       0.229154
# testID_past_count                                   0.469219
# testID_past_correct                                 0.648688
# testID_past_average_correct                         0.298315
# testID1_past_count                                  0.634255
# testID1_past_correct                                0.712152
# testID1_past_average_correct                        0.339401
# testID2_past_count                                  0.607072
# testID2_past_correct                                0.625907
# testID2_past_average_correct                       -0.031093
# testNum_past_count                                  0.614479
# testNum_past_correct                                0.595272
# testNum_past_average_correct                        0.046489
# KnowledgeTag_past_count                             0.959742
# KnowledgeTag_past_correct                           1.000000
# KnowledgeTag_past_average_correct                   0.320057
#
#                                    KnowledgeTag_past_average_correct
# answerCode                                                  0.284245
# question_past_count                                        -0.060619
# question_past_correct                                       0.246353
# question_past_average_correct                               0.650315
# testID_past_count                                          -0.213881
# testID_past_correct                                         0.088251
# testID_past_average_correct                                 0.866068
# testID1_past_count                                          0.061253
# testID1_past_correct                                        0.218575
# testID1_past_average_correct                                0.732196
# testID2_past_count                                         -0.116644
# testID2_past_correct                                       -0.078263
# testID2_past_average_correct                                0.341299
# testNum_past_count                                          0.108706
# testNum_past_correct                                        0.119987
# testNum_past_average_correct                                0.208066
# KnowledgeTag_past_count                                     0.121748
# KnowledgeTag_past_correct                                   0.320057
# KnowledgeTag_past_average_correct                           1.000000

# %%
df[['answerCode', 
    'user_question_past_count', 'user_question_past_correct', 'user_question_past_average_correct',
    'user_testID_past_count', 'user_testID_past_correct', 'user_testID_past_average_correct',
    'user_testID1_past_count', 'user_testID1_past_correct', 'user_testID1_past_average_correct',
    'user_testID2_past_count', 'user_testID2_past_correct', 'user_testID2_past_average_correct',
    'user_testNum_past_count', 'user_testNum_past_correct', 'user_testNum_past_average_correct',
    'user_KnowledgeTag_past_count', 'user_KnowledgeTag_past_correct', 'user_KnowledgeTag_past_average_correct']].corr()
# Out:
#                                         answerCode  user_question_past_count  \
# answerCode                                1.000000                 -0.004976
# user_question_past_count                 -0.004976                  1.000000
# user_question_past_correct                0.009079                  0.820548
# user_question_past_average_correct        0.009796                  0.811143
# user_testID_past_count                   -0.154971                  0.420927
# user_testID_past_correct                  0.114325                  0.337216
# user_testID_past_average_correct          0.258937                  0.028744
# user_testID1_past_count                   0.028464                  0.214107
# user_testID1_past_correct                 0.140285                  0.195015
# user_testID1_past_average_correct         0.407106                  0.010644
# user_testID2_past_count                  -0.122870                  0.278083
# user_testID2_past_correct                 0.070090                  0.234182
# user_testID2_past_average_correct         0.244501                  0.024525
# user_testNum_past_count                   0.056689                  0.092403
# user_testNum_past_correct                 0.119616                  0.085091
# user_testNum_past_average_correct         0.263451                  0.015453
# user_KnowledgeTag_past_count             -0.017581                  0.271382
# user_KnowledgeTag_past_correct            0.131991                  0.234789
# user_KnowledgeTag_past_average_correct    0.252647                  0.037339
#
#                                         user_question_past_correct  \
# answerCode                                                0.009079
# user_question_past_count                                  0.820548
# user_question_past_correct                                1.000000
# user_question_past_average_correct                        0.993276
# user_testID_past_count                                    0.325471
# user_testID_past_correct                                  0.327195
# user_testID_past_average_correct                          0.054267
# user_testID1_past_count                                   0.179895
# user_testID1_past_correct                                 0.182354
# user_testID1_past_average_correct                         0.033006
# user_testID2_past_count                                   0.215089
# user_testID2_past_correct                                 0.229341
# user_testID2_past_average_correct                         0.050995
# user_testNum_past_count                                   0.085107
# user_testNum_past_correct                                 0.089485
# user_testNum_past_average_correct                         0.038891
# user_KnowledgeTag_past_count                              0.228404
# user_KnowledgeTag_past_correct                            0.234906
# user_KnowledgeTag_past_average_correct                    0.062484
#
#                                         user_question_past_average_correct  \
# answerCode                                                        0.009796
# user_question_past_count                                          0.811143
# user_question_past_correct                                        0.993276
# user_question_past_average_correct                                1.000000
# user_testID_past_count                                            0.320178
# user_testID_past_correct                                          0.323722
# user_testID_past_average_correct                                  0.054887
# user_testID1_past_count                                           0.178446
# user_testID1_past_correct                                         0.182202
# user_testID1_past_average_correct                                 0.033822
# user_testID2_past_count                                           0.211786
# user_testID2_past_correct                                         0.227140
# user_testID2_past_average_correct                                 0.051601
# user_testNum_past_count                                           0.085326
# user_testNum_past_correct                                         0.090253
# user_testNum_past_average_correct                                 0.039637
# user_KnowledgeTag_past_count                                      0.224637
# user_KnowledgeTag_past_correct                                    0.232805
# user_KnowledgeTag_past_average_correct                            0.063162
#
#                                         user_testID_past_count  \
# answerCode                                           -0.154971
# user_question_past_count                              0.420927
# user_question_past_correct                            0.325471
# user_question_past_average_correct                    0.320178
# user_testID_past_count                                1.000000
# user_testID_past_correct                              0.761468
# user_testID_past_average_correct                      0.259411
# user_testID1_past_count                               0.120650
# user_testID1_past_correct                             0.079553
# user_testID1_past_average_correct                    -0.065049
# user_testID2_past_count                               0.698333
# user_testID2_past_correct                             0.560956
# user_testID2_past_average_correct                     0.230887
# user_testNum_past_count                              -0.124899
# user_testNum_past_correct                            -0.183577
# user_testNum_past_average_correct                    -0.301310
# user_KnowledgeTag_past_count                          0.379790
# user_KnowledgeTag_past_correct                        0.300574
# user_KnowledgeTag_past_average_correct                0.183337
#
#                                         user_testID_past_correct  \
# answerCode                                              0.114325
# user_question_past_count                                0.337216
# user_question_past_correct                              0.327195
# user_question_past_average_correct                      0.323722
# user_testID_past_count                                  0.761468
# user_testID_past_correct                                1.000000
# user_testID_past_average_correct                        0.647945
# user_testID1_past_count                                 0.121972
# user_testID1_past_correct                               0.185383
# user_testID1_past_average_correct                       0.303248
# user_testID2_past_count                                 0.519530
# user_testID2_past_correct                               0.722224
# user_testID2_past_average_correct                       0.602666
# user_testNum_past_count                                -0.065098
# user_testNum_past_correct                              -0.074443
# user_testNum_past_average_correct                      -0.059195
# user_KnowledgeTag_past_count                            0.339897
# user_KnowledgeTag_past_correct                          0.472047
# user_KnowledgeTag_past_average_correct                  0.514894
#
#                                         user_testID_past_average_correct  \
# answerCode                                                      0.258937
# user_question_past_count                                        0.028744
# user_question_past_correct                                      0.054267
# user_question_past_average_correct                              0.054887
# user_testID_past_count                                          0.259411
# user_testID_past_correct                                        0.647945
# user_testID_past_average_correct                                1.000000
# user_testID1_past_count                                         0.042515
# user_testID1_past_correct                                       0.147510
# user_testID1_past_average_correct                               0.461161
# user_testID2_past_count                                         0.165107
# user_testID2_past_correct                                       0.459169
# user_testID2_past_average_correct                               0.926923
# user_testNum_past_count                                         0.017280
# user_testNum_past_correct                                       0.040045
# user_testNum_past_average_correct                               0.120195
# user_KnowledgeTag_past_count                                    0.162661
# user_KnowledgeTag_past_correct                                  0.364380
# user_KnowledgeTag_past_average_correct                          0.747775
#
#                                         user_testID1_past_count  \
# answerCode                                             0.028464
# user_question_past_count                               0.214107
# user_question_past_correct                             0.179895
# user_question_past_average_correct                     0.178446
# user_testID_past_count                                 0.120650
# user_testID_past_correct                               0.121972
# user_testID_past_average_correct                       0.042515
# user_testID1_past_count                                1.000000
# user_testID1_past_correct                              0.927721
# user_testID1_past_average_correct                      0.081609
# user_testID2_past_count                                0.131070
# user_testID2_past_correct                              0.134065
# user_testID2_past_average_correct                      0.048906
# user_testNum_past_count                                0.721306
# user_testNum_past_correct                              0.670200
# user_testNum_past_average_correct                      0.118452
# user_KnowledgeTag_past_count                           0.310366
# user_KnowledgeTag_past_correct                         0.295089
# user_KnowledgeTag_past_average_correct                 0.080369
#
#                                         user_testID1_past_correct  \
# answerCode                                               0.140285
# user_question_past_count                                 0.195015
# user_question_past_correct                               0.182354
# user_question_past_average_correct                       0.182202
# user_testID_past_count                                   0.079553
# user_testID_past_correct                                 0.185383
# user_testID_past_average_correct                         0.147510
# user_testID1_past_count                                  0.927721
# user_testID1_past_correct                                1.000000
# user_testID1_past_average_correct                        0.312677
# user_testID2_past_count                                  0.083232
# user_testID2_past_correct                                0.164678
# user_testID2_past_average_correct                        0.143248
# user_testNum_past_count                                  0.684567
# user_testNum_past_correct                                0.707547
# user_testNum_past_average_correct                        0.257680
# user_KnowledgeTag_past_count                             0.312965
# user_KnowledgeTag_past_correct                           0.372230
# user_KnowledgeTag_past_average_correct                   0.191418
#
#                                         user_testID1_past_average_correct  \
# answerCode                                                       0.407106
# user_question_past_count                                         0.010644
# user_question_past_correct                                       0.033006
# user_question_past_average_correct                               0.033822
# user_testID_past_count                                          -0.065049
# user_testID_past_correct                                         0.303248
# user_testID_past_average_correct                                 0.461161
# user_testID1_past_count                                          0.081609
# user_testID1_past_correct                                        0.312677
# user_testID1_past_average_correct                                1.000000
# user_testID2_past_count                                         -0.075799
# user_testID2_past_correct                                        0.194945
# user_testID2_past_average_correct                                0.433909
# user_testNum_past_count                                          0.085809
# user_testNum_past_correct                                        0.198236
# user_testNum_past_average_correct                                0.503093
# user_KnowledgeTag_past_count                                     0.082906
# user_KnowledgeTag_past_correct                                   0.294316
# user_KnowledgeTag_past_average_correct                           0.468288
#
#                                         user_testID2_past_count  \
# answerCode                                            -0.122870
# user_question_past_count                               0.278083
# user_question_past_correct                             0.215089
# user_question_past_average_correct                     0.211786
# user_testID_past_count                                 0.698333
# user_testID_past_correct                               0.519530
# user_testID_past_average_correct                       0.165107
# user_testID1_past_count                                0.131070
# user_testID1_past_correct                              0.083232
# user_testID1_past_average_correct                     -0.075799
# user_testID2_past_count                                1.000000
# user_testID2_past_correct                              0.833006
# user_testID2_past_average_correct                      0.207822
# user_testNum_past_count                                0.082313
# user_testNum_past_correct                              0.029406
# user_testNum_past_average_correct                     -0.183545
# user_KnowledgeTag_past_count                           0.295532
# user_KnowledgeTag_past_correct                         0.228862
# user_KnowledgeTag_past_average_correct                 0.114808
#
#                                         user_testID2_past_correct  \
# answerCode                                               0.070090
# user_question_past_count                                 0.234182
# user_question_past_correct                               0.229341
# user_question_past_average_correct                       0.227140
# user_testID_past_count                                   0.560956
# user_testID_past_correct                                 0.722224
# user_testID_past_average_correct                         0.459169
# user_testID1_past_count                                  0.134065
# user_testID1_past_correct                                0.164678
# user_testID1_past_average_correct                        0.194945
# user_testID2_past_count                                  0.833006
# user_testID2_past_correct                                1.000000
# user_testID2_past_average_correct                        0.536309
# user_testNum_past_count                                  0.112925
# user_testNum_past_correct                                0.107683
# user_testNum_past_average_correct                        0.005695
# user_KnowledgeTag_past_count                             0.273648
# user_KnowledgeTag_past_correct                           0.360423
# user_KnowledgeTag_past_average_correct                   0.364142
#
#                                         user_testID2_past_average_correct  \
# answerCode                                                       0.244501
# user_question_past_count                                         0.024525
# user_question_past_correct                                       0.050995
# user_question_past_average_correct                               0.051601
# user_testID_past_count                                           0.230887
# user_testID_past_correct                                         0.602666
# user_testID_past_average_correct                                 0.926923
# user_testID1_past_count                                          0.048906
# user_testID1_past_correct                                        0.143248
# user_testID1_past_average_correct                                0.433909
# user_testID2_past_count                                          0.207822
# user_testID2_past_correct                                        0.536309
# user_testID2_past_average_correct                                1.000000
# user_testNum_past_count                                          0.052469
# user_testNum_past_correct                                        0.081934
# user_testNum_past_average_correct                                0.145433
# user_KnowledgeTag_past_count                                     0.149975
# user_KnowledgeTag_past_correct                                   0.340756
# user_KnowledgeTag_past_average_correct                           0.702619
#
#                                         user_testNum_past_count  \
# answerCode                                             0.056689
# user_question_past_count                               0.092403
# user_question_past_correct                             0.085107
# user_question_past_average_correct                     0.085326
# user_testID_past_count                                -0.124899
# user_testID_past_correct                              -0.065098
# user_testID_past_average_correct                       0.017280
# user_testID1_past_count                                0.721306
# user_testID1_past_correct                              0.684567
# user_testID1_past_average_correct                      0.085809
# user_testID2_past_count                                0.082313
# user_testID2_past_correct                              0.112925
# user_testID2_past_average_correct                      0.052469
# user_testNum_past_count                                1.000000
# user_testNum_past_correct                              0.956298
# user_testNum_past_average_correct                      0.210236
# user_KnowledgeTag_past_count                           0.157627
# user_KnowledgeTag_past_correct                         0.167480
# user_KnowledgeTag_past_average_correct                 0.055588
#
#                                         user_testNum_past_correct  \
# answerCode                                               0.119616
# user_question_past_count                                 0.085091
# user_question_past_correct                               0.089485
# user_question_past_average_correct                       0.090253
# user_testID_past_count                                  -0.183577
# user_testID_past_correct                                -0.074443
# user_testID_past_average_correct                         0.040045
# user_testID1_past_count                                  0.670200
# user_testID1_past_correct                                0.707547
# user_testID1_past_average_correct                        0.198236
# user_testID2_past_count                                  0.029406
# user_testID2_past_correct                                0.107683
# user_testID2_past_average_correct                        0.081934
# user_testNum_past_count                                  0.956298
# user_testNum_past_correct                                1.000000
# user_testNum_past_average_correct                        0.356530
# user_KnowledgeTag_past_count                             0.137209
# user_KnowledgeTag_past_correct                           0.184522
# user_KnowledgeTag_past_average_correct                   0.089630
#
#                                         user_testNum_past_average_correct  \
# answerCode                                                       0.263451
# user_question_past_count                                         0.015453
# user_question_past_correct                                       0.038891
# user_question_past_average_correct                               0.039637
# user_testID_past_count                                          -0.301310
# user_testID_past_correct                                        -0.059195
# user_testID_past_average_correct                                 0.120195
# user_testID1_past_count                                          0.118452
# user_testID1_past_correct                                        0.257680
# user_testID1_past_average_correct                                0.503093
# user_testID2_past_count                                         -0.183545
# user_testID2_past_correct                                        0.005695
# user_testID2_past_average_correct                                0.145433
# user_testNum_past_count                                          0.210236
# user_testNum_past_correct                                        0.356530
# user_testNum_past_average_correct                                1.000000
# user_KnowledgeTag_past_count                                    -0.018270
# user_KnowledgeTag_past_correct                                   0.108443
# user_KnowledgeTag_past_average_correct                           0.160047
#
#                                         user_KnowledgeTag_past_count  \
# answerCode                                                 -0.017581
# user_question_past_count                                    0.271382
# user_question_past_correct                                  0.228404
# user_question_past_average_correct                          0.224637
# user_testID_past_count                                      0.379790
# user_testID_past_correct                                    0.339897
# user_testID_past_average_correct                            0.162661
# user_testID1_past_count                                     0.310366
# user_testID1_past_correct                                   0.312965
# user_testID1_past_average_correct                           0.082906
# user_testID2_past_count                                     0.295532
# user_testID2_past_correct                                   0.273648
# user_testID2_past_average_correct                           0.149975
# user_testNum_past_count                                     0.157627
# user_testNum_past_correct                                   0.137209
# user_testNum_past_average_correct                          -0.018270
# user_KnowledgeTag_past_count                                1.000000
# user_KnowledgeTag_past_correct                              0.879949
# user_KnowledgeTag_past_average_correct                      0.282832
#
#                                         user_KnowledgeTag_past_correct  \
# answerCode                                                    0.131991
# user_question_past_count                                      0.234789
# user_question_past_correct                                    0.234906
# user_question_past_average_correct                            0.232805
# user_testID_past_count                                        0.300574
# user_testID_past_correct                                      0.472047
# user_testID_past_average_correct                              0.364380
# user_testID1_past_count                                       0.295089
# user_testID1_past_correct                                     0.372230
# user_testID1_past_average_correct                             0.294316
# user_testID2_past_count                                       0.228862
# user_testID2_past_correct                                     0.360423
# user_testID2_past_average_correct                             0.340756
# user_testNum_past_count                                       0.167480
# user_testNum_past_correct                                     0.184522
# user_testNum_past_average_correct                             0.108443
# user_KnowledgeTag_past_count                                  0.879949
# user_KnowledgeTag_past_correct                                1.000000
# user_KnowledgeTag_past_average_correct                        0.509696
#
#                                         user_KnowledgeTag_past_average_correct
# answerCode                                                            0.252647
# user_question_past_count                                              0.037339
# user_question_past_correct                                            0.062484
# user_question_past_average_correct                                    0.063162
# user_testID_past_count                                                0.183337
# user_testID_past_correct                                              0.514894
# user_testID_past_average_correct                                      0.747775
# user_testID1_past_count                                               0.080369
# user_testID1_past_correct                                             0.191418
# user_testID1_past_average_correct                                     0.468288
# user_testID2_past_count                                               0.114808
# user_testID2_past_correct                                             0.364142
# user_testID2_past_average_correct                                     0.702619
# user_testNum_past_count                                               0.055588
# user_testNum_past_correct                                             0.089630
# user_testNum_past_average_correct                                     0.160047
# user_KnowledgeTag_past_count                                          0.282832
# user_KnowledgeTag_past_correct                                        0.509696
# user_KnowledgeTag_past_average_correct                                1.000000
